# %%
import os
# Find the latest version of spark 3.x  from https://downloads.apache.org/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.5.1'
spark_version = 'spark-3.5.5'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 391 kB in 5s (74.5 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# Start Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("RestaurantInspections").getOrCreate()

# %%
# Specify the file path to your local CSV file
file_path = "/content/ARCHIVED__Restaurant_Inspection_Scores__2016-2019__20250310.csv"  # Replace with your actual file path

# Read CSV file into Spark DataFrame
df = spark.read.csv(file_path, header=True, inferSchema=True)

# Show the first few rows of the DataFrame to verify it loaded correctly
df.show()
# Out:
# +-----------+--------------------+--------------------+-------------+--------------+--------------------+-----------------+------------------+--------------------+---------------------+---------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+-------------+---------------------+------------------------+----------------------------+----------------------+
# |business_id|       business_name|    business_address|business_city|business_state|business_postal_code|business_latitude|business_longitude|   business_location|business_phone_number|  inspection_id|     inspection_date|inspection_score|     inspection_type|        violation_id|violation_description|risk_category|Neighborhoods|SF Find Neighborhoods|Current Police Districts|Current Supervisor Districts|Analysis Neighborhoods|
# +-----------+--------------------+--------------------+-------------+--------------+--------------------+-----------------+------------------+--------------------+---------------------+---------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+-------------+---------------------+------------------------+----------------------------+----------------------+
# |      85936|        Laurel Court|        950 Mason St|San Francisco|            CA|               94108|             NULL|              NULL|                NULL|          14155775000| 85936_20170925|09/25/2017 12:00:...|             100|Routine - Unsched...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |       5827|HILLCREST ELEMENT...|      810 SILVER Ave|San Francisco|            CA|               94134|        37.729016|       -122.419253|POINT (-122.41925...|          14155464722|  5827_20170224|02/24/2017 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|           92|                   92|                       2|                           2|                     7|
# |      94910|       Ike's Kitchen|    800 Van Ness Ave|San Francisco|            CA|               94109|             NULL|              NULL|                NULL|                 NULL| 94910_20180530|05/30/2018 12:00:...|            NULL|New Ownership - F...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |      64667|  Jasmine Rae Bakery| 1890 Bryant St #309|San Francisco|            CA|               94110|        37.763156|       -122.410351|POINT (-122.41035...|                 NULL| 64667_20170814|08/14/2017 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|           53|                   53|                       3|                           2|                    20|
# |      97722|  THE CHURRO FACTORY|       PIER 39  K-01|San Francisco|            CA|               94133|             NULL|              NULL|                NULL|                 NULL| 97722_20181217|12/17/2018 12:00:...|              96|Routine - Unsched...|97722_20181217_10...| Unclean or degrad...|     Low Risk|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |      87203|          The Morris|    2501 Mariposa St|San Francisco|            CA|               94110|             NULL|              NULL|                NULL|          14150710693| 87203_20171106|11/06/2017 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |       1710|Emporio Rulli Il ...|     225 Stockton St|San Francisco|            CA|               94108|        37.787936|       -122.406712|POINT (-122.40671...|                 NULL|  1710_20180423|04/23/2018 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|           19|                   19|                       6|                           3|                     8|
# |      92928|       Cafe Reveille|      201 Steiner St|San Francisco|            CA|               94117|             NULL|              NULL|                NULL|                 NULL| 92928_20180118|01/18/2018 12:00:...|            NULL|    New Construction|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |      90840|Steep Creamery & Tea|270 Brannan St., ...|San Francisco|            CA|               94107|             NULL|              NULL|                NULL|                 NULL| 90840_20171017|10/17/2017 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |        272|       ON THE BRIDGE|1581 Webster St #206|San Francisco|            CA|               94115|        37.785227|       -122.431472|POINT (-122.43147...|          14155927765|   272_20180611|06/11/2018 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|          101|                  101|                       4|                          11|                    15|
# |      92530|      Taqueria Zorro|    308 Columbus Ave|San Francisco|            CA|               94133|             NULL|              NULL|                NULL|          14155399677| 92530_20190823|08/23/2019 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |     100879|LORENZO'S OF NEW ...|        2109 POLK ST|San Francisco|            CA|               94109|             NULL|              NULL|                NULL|          14150980339|100879_20190611|06/11/2019 12:00:...|            NULL|       New Ownership|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |      95023|             Sakesan|      1400 Ocean Ave|San Francisco|            CA|               94112|             NULL|              NULL|                NULL|                 NULL| 95023_20180510|05/10/2018 12:00:...|              92|Routine - Unsched...|95023_20180510_10...| Wiping cloths not...|     Low Risk|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |      93362|       Cafe Valencia|   1252 Valencia St.|San Francisco|            CA|               94110|             NULL|              NULL|                NULL|                 NULL| 93362_20190426|04/26/2019 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |       3072|HOTEL UTAH SALOON...|         500 04th St|San Francisco|            CA|               94107|        37.779522|       -122.398104|POINT (-122.39810...|                 NULL|  3072_20180309|03/09/2018 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|           32|                   32|                       1|                          10|                    34|
# |      94977|94977 Portables 2...|24 Willie Mays Pl...|San Francisco|            CA|               94107|             NULL|              NULL|                NULL|                 NULL| 94977_20180911|09/11/2018 12:00:...|              96|Routine - Unsched...|94977_20180911_10...| Inadequate and in...|Moderate Risk|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |     101175|         THE UP & UP|      1268 GRANT AVE|San Francisco|            CA|               94133|             NULL|              NULL|                NULL|          14155379736|101175_20190703|07/03/2019 12:00:...|            NULL|New Ownership - F...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# |       3838|         CAFE PICARO|        3120 16th St|San Francisco|            CA|               94103|        37.764908|       -122.422442|POINT (-122.42244...|          14155434089|  3838_20180320|03/20/2018 12:00:...|            NULL|Reinspection/Foll...|                NULL|                 NULL|         NULL|           37|                   37|                       3|                           5|                    20|
# |      61056|Town School For Boys|     2750 JACKSON St|San Francisco|            CA|               94115|        37.791777|       -122.440355|POINT (-122.44035...|                 NULL| 61056_20161026|10/26/2016 12:00:...|            NULL|           Complaint|                NULL|                 NULL|         NULL|          102|                  102|                       4|                           6|                    30|
# |      94943|  94943 Hearth Table|24 Willie Mays Pl...|San Francisco|            CA|               94107|             NULL|              NULL|                NULL|                 NULL| 94943_20190412|04/12/2019 12:00:...|             100|Routine - Unsched...|                NULL|                 NULL|         NULL|         NULL|                 NULL|                    NULL|                        NULL|                  NULL|
# +-----------+--------------------+--------------------+-------------+--------------+--------------------+-----------------+------------------+--------------------+---------------------+---------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+-------------+---------------------+------------------------+----------------------------+----------------------+
# only showing top 20 rows

# %%
# Get the number of rows
num_rows = df.count()

# Print the result
print(f"Number of rows in the DataFrame: {num_rows}")
# Out:
# Number of rows in the DataFrame: 53973

# %%
df.printSchema()
# Out:
# root
#  |-- business_id: integer (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- business_address: string (nullable = true)
#  |-- business_city: string (nullable = true)
#  |-- business_state: string (nullable = true)
#  |-- business_postal_code: string (nullable = true)
#  |-- business_latitude: double (nullable = true)
#  |-- business_longitude: double (nullable = true)
#  |-- business_location: string (nullable = true)
#  |-- business_phone_number: long (nullable = true)
#  |-- inspection_id: string (nullable = true)
#  |-- inspection_date: string (nullable = true)
#  |-- inspection_score: integer (nullable = true)
#  |-- inspection_type: string (nullable = true)
#  |-- violation_id: string (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- risk_category: string (nullable = true)
#  |-- Neighborhoods: integer (nullable = true)
#  |-- SF Find Neighborhoods: integer (nullable = true)
#  |-- Current Police Districts: integer (nullable = true)
#  |-- Current Supervisor Districts: integer (nullable = true)
#  |-- Analysis Neighborhoods: integer (nullable = true)

# %%
df_drop=df.dropna()
df_drop.show()
# Out:
# +-----------+--------------------+--------------------+-------------+--------------+--------------------+-----------------+------------------+--------------------+---------------------+--------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+-------------+---------------------+------------------------+----------------------------+----------------------+
# |business_id|       business_name|    business_address|business_city|business_state|business_postal_code|business_latitude|business_longitude|   business_location|business_phone_number| inspection_id|     inspection_date|inspection_score|     inspection_type|        violation_id|violation_description|risk_category|Neighborhoods|SF Find Neighborhoods|Current Police Districts|Current Supervisor Districts|Analysis Neighborhoods|
# +-----------+--------------------+--------------------+-------------+--------------+--------------------+-----------------+------------------+--------------------+---------------------+--------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+-------------+---------------------+------------------------+----------------------------+----------------------+

# |       1300|         WE BE SUSHI|    1071 VALENCIA St|San Francisco|            CA|               94110|        37.755824|       -122.420986|POINT (-122.42098...|          14155820607| 1300_20171005|10/05/2017 12:00:...|              74|Routine - Unsched...|1300_20171005_103154| Unclean or degrad...|     Low Risk|           53|                   53|                       3|                           2|                    20|
# |        557|           TASTEBUDS|        600 05th Ave|San Francisco|            CA|               94118|         37.77721|       -122.462874|POINT (-122.46287...|          14155669292|  557_20180905|09/05/2018 12:00:...|              83|Routine - Unsched...| 557_20180905_103109| Unclean or unsani...|    High Risk|            5|                    5|                       8|                           4|                    11|
# |       1664|       PANDA EXPRESS|   865 MARKET St C24|San Francisco|            CA|               94103|        37.784317|       -122.407563|POINT (-122.40756...|          14155249775| 1664_20190822|08/22/2019 12:00:...|              96|Routine - Unsched...|1664_20190822_103124| Inadequately clea...|Moderate Risk|           32|                   32|                       5|                          10|                    34|
# |      32671|La Taqueria Guada...|        3146 24th St|San Francisco|            CA|               94110|        37.752512|       -122.415109|POINT (-122.41510...|          14155644892|32671_20180508|05/08/2018 12:00:...|              75|Routine - Unsched...|32671_20180508_10...| Foods not protect...|Moderate Risk|           53|                   53|                       3|                           2|                    20|
# |       3165|         HAN IL KWAN|      1802 BALBOA St|San Francisco|            CA|               94121|        37.776599|       -122.478292|POINT (-122.47829...|          14153598244| 3165_20181127|11/27/2018 12:00:...|              83|Routine - Unsched...|3165_20181127_103144| Unapproved or unm...|     Low Risk|            8|                    8|                       8|                           4|                    29|
# |      33160|    Mission Bay Cafe|550 Terry Francoi...|San Francisco|            CA|               94158|        37.770518|       -122.386525|POINT (-122.38652...|          14155831002|33160_20161205|12/05/2016 12:00:...|              94|Routine - Unsched...|33160_20161205_10...| Moderate risk foo...|Moderate Risk|           34|                   34|                       1|                          10|                     4|
# |        943|EL CASTILLITO TAQ...|       136 CHURCH St|San Francisco|            CA|               94114|        37.768776|       -122.429095|POINT (-122.42909...|          14155623428|  943_20180426|04/26/2018 12:00:...|              76|Routine - Unsched...| 943_20180426_103119| Inadequate and in...|Moderate Risk|           28|                   28|                       7|                           5|                     5|
# |       4874|JUMP START COFFEE...|    1192 GUERRERO St|San Francisco|            CA|               94110|        37.752118|       -122.422914|POINT (-122.42291...|          14155647555| 4874_20170815|08/15/2017 12:00:...|              88|Routine - Unsched...|4874_20170815_103142| Unclean nonfood c...|     Low Risk|           52|                   52|                       3|                           5|                    20|
# |       1426|SWEET DELIGHT BAKERY|       4476A MISSION|San Francisco|            CA|               94112|        37.726117|       -122.433817|POINT (-122.43381...|          14155336786| 1426_20161026|10/26/2016 12:00:...|              70|Routine - Unsched...|1426_20161026_103121| Inadequate proced...|Moderate Risk|           94|                   94|                       9|                           1|                    28|
# +-----------+--------------------+--------------------+-------------+--------------+--------------------+-----------------+------------------+--------------------+---------------------+--------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+-------------+---------------------+------------------------+----------------------------+----------------------+
# only showing top 20 rows

# %%
# Get the number of rows
num_rows = df_drop.count()

# Print the result
print(f"Number of rows in the DataFrame: {num_rows}")
# Out:
# Number of rows in the DataFrame: 5205

# %%
columns_to_remove = ["business_city", "business_state", "business_phone_number",
                     'business_location', 'Neighborhoods', 'SF Find Neighborhoods',
                     'Current Police Districts', 'Current Supervisor Districts', 'Analysis Neighborhoods']
                     # Get the list of existing columns to remove (checking if they exist in the DataFrame)
existing_columns_to_remove = [col for col in columns_to_remove if col in df.columns]
# Drop the columns that exist in the DataFrame
prepared_df = df_drop.drop(*existing_columns_to_remove)
prepared_df.show()
# Out:
# +-----------+--------------------+--------------------+--------------------+-----------------+------------------+--------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------+
# |business_id|       business_name|    business_address|business_postal_code|business_latitude|business_longitude| inspection_id|     inspection_date|inspection_score|     inspection_type|        violation_id|violation_description|risk_category|
# +-----------+--------------------+--------------------+--------------------+-----------------+------------------+--------------+--------------------+----------------+--------------------+--------------------+---------------------+-------------

# |       1300|         WE BE SUSHI|    1071 VALENCIA St|               94110|        37.755824|       -122.420986| 130020171005|10/05/2017 12:00:...|              74|Routine - Unsched...| 130020171005103154| Unclean or degrad...|     Low Risk|
# |        557|           TASTEBUDS|        600 05th Ave|               94118|         37.77721|       -122.462874|  55720180905|09/05/2018 12:00:...|              83|Routine - Unsched...|  55720180905103109| Unclean or unsani...|    High Risk|
# |       1664|       PANDA EXPRESS|   865 MARKET St C24|               94103|        37.784317|       -122.407563| 166420190822|08/22/2019 12:00:...|              96|Routine - Unsched...| 166420190822103124| Inadequately clea...|Moderate Risk|
# |      32671|La Taqueria Guada...|        3146 24th St|               94110|        37.752512|       -122.415109|3267120180508|05/08/2018 12:00:...|              75|Routine - Unsched...|3267120180508103133| Foods not protect...|Moderate Risk|
# |       3165|         HAN IL KWAN|      1802 BALBOA St|               94121|        37.776599|       -122.478292| 316520181127|11/27/2018 12:00:...|              83|Routine - Unsched...| 316520181127103144| Unapproved or unm...|     Low Risk|
# |      33160|    Mission Bay Cafe|550 Terry Francoi...|               94158|        37.770518|       -122.386525|3316020161205|12/05/2016 12:00:...|              94|Routine - Unsched...|3316020161205103120| Moderate risk foo...|Moderate Risk|
# |        943|EL CASTILLITO TAQ...|       136 CHURCH St|               94114|        37.768776|       -122.429095|  94320180426|04/26/2018 12:00:...|              76|Routine - Unsched...|  94320180426103119| Inadequate and in...|Moderate Risk|
# |       4874|JUMP START COFFEE...|    1192 GUERRERO St|               94110|        37.752118|       -122.422914| 487420170815|08/15/2017 12:00:...|              88|Routine - Unsched...| 487420170815103142| Unclean nonfood c...|     Low Risk|
# |       1426|SWEET DELIGHT BAKERY|       4476A MISSION|               94112|        37.726117|       -122.433817| 142620161026|10/26/2016 12:00:...|              70|Routine - Unsched...| 142620161026103121| Inadequate proced...|Moderate Risk|
# +-----------+--------------------+--------------------+--------------------+-----------------+------------------+-------------+--------------------+----------------+--------------------+-------------------+---------------------+-------------+
# only showing top 20 rows

# %%
df_cleaned.printSchema()
# Out:
# root
#  |-- business_id: integer (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- business_address: string (nullable = true)
#  |-- business_postal_code: string (nullable = true)
#  |-- business_latitude: double (nullable = true)
#  |-- business_longitude: double (nullable = true)
#  |-- inspection_id: long (nullable = true)
#  |-- inspection_date: string (nullable = true)
#  |-- inspection_score: integer (nullable = true)
#  |-- inspection_type: string (nullable = true)
#  |-- violation_id: long (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- risk_category: string (nullable = true)

# %%
from pyspark.sql.functions import col, split,to_date
# Show the original data
df_cleaned.show(truncate=False)
# Split the 'inspection_date' column by space to separate date and time
df_split = df_cleaned.withColumn("date", split(col("inspection_date"), " ").getItem(0)) \
             .withColumn("time", split(col("inspection_date"), " ").getItem(1))
# Show the new DataFrame
df_split.show()
# Out:
# +-----------+-----------------------------------+---------------------+--------------------+-----------------+------------------+-------------+----------------------+----------------+---------------------+-------------------+--------------------------------------------------------------------+-------------+
# |business_id|business_name                      |business_address     |business_postal_code|business_latitude|business_longitude|inspection_id|inspection_date       |inspection_score|inspection_type      |violation_id       |violation_description                                               |risk_category|
# +-----------+-----------------------------------+---------------------+--------------------+-----------------+------------------+-------------+----------------------+----------------+---------------------+-------------------+--------------------------------------------------------------------+-------------+
# |3649       |SAFEWAY #1490                      |2300 16th St         |94103               |37.765708        |-122.409002       |364920171206 |12/06/2017 12:00:00 AM|82              |Routine - Unscheduled|364920171206103131 |Moderate risk vermin infestation                                    |Moderate Risk|
# |184        |RADIO HABANA                       |1109 VALENCIA St     |94110               |37.755124        |-122.420916       |18420180213  |02/13/2018 12:00:00 AM|90              |Routine - Unscheduled|18420180213103129  |Insufficient hot water or running water                             |Moderate Risk|
# |1154       |SUNFLOWER RESTAURANT               |506 Valencia St      |94103               |37.764678        |-122.421905       |115420190327 |03/27/2019 12:00:00 AM|46              |Routine - Unscheduled|115420190327103119 |Inadequate and inaccessible handwashing facilities                  |Moderate Risk|

# |       1426|SWEET DELIGHT BAKERY|       4476A MISSION|               94112|        37.726117|       -122.433817| 142620161026|10/26/2016 12:00:...|              70|Routine - Unsched...| 142620161026103121| Inadequate proced...|Moderate Risk|10/26/2016|12:00:00|
# +-----------+--------------------+--------------------+--------------------+-----------------+------------------+-------------+--------------------+----------------+--------------------+-------------------+---------------------+-------------+----------+--------+
# only showing top 20 rows

# %%
df_split.printSchema()
# Out:
# root
#  |-- business_id: integer (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- business_address: string (nullable = true)
#  |-- business_postal_code: string (nullable = true)
#  |-- business_latitude: double (nullable = true)
#  |-- business_longitude: double (nullable = true)
#  |-- inspection_id: long (nullable = true)
#  |-- inspection_date: string (nullable = true)
#  |-- inspection_score: integer (nullable = true)
#  |-- inspection_type: string (nullable = true)
#  |-- violation_id: long (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- risk_category: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- time: string (nullable = true)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date, to_timestamp, isnotnull

# Initialize Spark Session
spark = SparkSession.builder.appName("ChangeColumnTypes").getOrCreate()

# Set legacy time parser policy
spark.conf.set("spark.sql.legacy.timeParserPolicy", "LEGACY")

# Convert Columns
df_cleaned = df_split.withColumn("business_id", col("business_id").cast("int")) \
               .withColumn("inspection_id", col("inspection_id").cast("int")) \
               .withColumn("inspection_score", col("inspection_score").cast("int")) \
               .withColumn("violation_id", col("violation_id").cast("int")) \
               .withColumn("business_postal_code", col("business_postal_code").cast("int")) \
               .withColumn("inspection_date", to_date(col("inspection_date"), "MM/dd/yyyy hh:mm:ss a")) \
               .withColumn("date", to_date(col("date"), "MM/dd/yyyy")) \
               .withColumn("time", to_timestamp(col("time"), "HH:mm:ss"))  # Convert time to timestamp

# Show Schema After Conversion
df_cleaned.printSchema()

# Show Data
df_cleaned.show()
# Out:
# root
#  |-- business_id: integer (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- business_address: string (nullable = true)
#  |-- business_postal_code: integer (nullable = true)
#  |-- business_latitude: double (nullable = true)
#  |-- business_longitude: double (nullable = true)
#  |-- inspection_id: integer (nullable = true)
#  |-- inspection_date: date (nullable = true)
#  |-- inspection_score: integer (nullable = true)
#  |-- inspection_type: string (nullable = true)
#  |-- violation_id: integer (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- risk_category: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- time: timestamp (nullable = true)
#
# +-----------+--------------------+--------------------+--------------------+-----------------+------------------+-------------+---------------+----------------+--------------------+------------+---------------------+-------------+----------+-------------------+
# |business_id|       business_name|    business_address|business_postal_code|business_latitude|business_longitude|inspection_id|inspection_date|inspection_score|     inspection_type|violation_id|violation_description|risk_category|      date|               time|
# +-----------+--------------------+--------------------+--------------------+-----------------+------------------+-------------+---------------+----------------+--------------------+------------+---------------------+-------------+----------+-------------------+
# |       3649|       SAFEWAY #1490|        2300 16th St|               94103|        37.765708|       -122.409002|   -152048954|     2017-12-06|              82|Routine - Unsched...|  1478316123| Moderate risk ver...|Moderate Risk|2017-12-06|1970-01-01 12:00:00|
# |        184|        RADIO HABANA|    1109 VALENCIA St|               94110|        37.755124|       -122.420916|   1240311029|     2018-02-13|              90|Routine - Unsched...|  1783429657| Insufficient hot ...|Moderate Risk|2018-02-13|1970-01-01 12:00:00|
# |       1154|SUNFLOWER RESTAURANT|     506 Valencia St|               94103|        37.764678|       -122.421905|   -543926665|     2019-03-27|              46|Routine - Unsched...|   878370447| Inadequate and in...|Moderate Risk|2019-03-27|1970-01-01 12:00:00|
# |       1636|                AXUM|       698 Haight St|               94117|        37.771738|       -122.433583|    411423755|     2018-10-03|              88|Routine - Unsched...|   247884717| Wiping cloths not...|     Low Risk|2018-10-03|1970-01-01 12:00:00|
# |       7764|YASUKOCHI'S SWEET...|      1790 SUTTER St|               94115|         37.78659|       -122.429815|   -968899858|     2018-07-18|              90|Routine - Unsched...|  1814407794| Unclean or degrad...|     Low Risk|2018-07-18|1970-01-01 12:00:00|
# |      37482|               Bursa| 60 West Portal Ave.|               94127|        37.740144|       -122.466569|  -1286269186|     2018-02-22|              92|Routine - Unsched...|   504811088| Moderate risk foo...|Moderate Risk|2018-02-22|1970-01-01 12:00:00|
# |      59044|  Taqueria Cazadores|   1600 C Mission St|               94110|        37.749851|       -122.415121|  -1159851878|     2018-01-22|              78|Routine - Unsched...|  -254579377| Inadequate and in...|Moderate Risk|2018-01-22|1970-01-01 12:00:00|
# %%
df_cleaned.printSchema()
# Out:
# root
#  |-- business_id: integer (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- business_address: string (nullable = true)
#  |-- business_postal_code: integer (nullable = true)
#  |-- business_latitude: double (nullable = true)
#  |-- business_longitude: double (nullable = true)
#  |-- inspection_id: integer (nullable = true)
#  |-- inspection_date: date (nullable = true)
#  |-- inspection_score: integer (nullable = true)
#  |-- inspection_type: string (nullable = true)
#  |-- violation_id: integer (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- risk_category: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- time: timestamp (nullable = true)

# %%
df_cleaned.write.csv("/content/data_cleaned.csv", header=True, mode="overwrite")

# %%
# !zip -r /content/cleaned_restaurant_inspections_single.zip /content/data_cleaned.csv
#Zipping the CSV file that was created in a previous code block.
from google.colab import files
files.download('/content/cleaned_restaurant_inspections_single.zip')
#Downloading the zipped file
# Out:
# updating: content/data_cleaned.csv/ (stored 0%)
# updating: content/data_cleaned.csv/._SUCCESS.crc (stored 0%)
# updating: content/data_cleaned.csv/_SUCCESS (stored 0%)
#   adding: content/data_cleaned.csv/.part-00000-45776bff-1100-46e3-9c5c-838c2f0cd3cc-c000.csv.crc (stored 0%)
#   adding: content/data_cleaned.csv/part-00000-45776bff-1100-46e3-9c5c-838c2f0cd3cc-c000.csv (deflated 78%)
#   adding: content/data_cleaned.csv/part-00001-45776bff-1100-46e3-9c5c-838c2f0cd3cc-c000.csv (deflated 81%)
#   adding: content/data_cleaned.csv/.part-00001-45776bff-1100-46e3-9c5c-838c2f0cd3cc-c000.csv.crc (stored 0%)

# %%
# Convert Spark DataFrame to Pandas
pandas_df = df_cleaned.toPandas()

pandas_df
# Out:
#       business_id            business_name   business_address  \
# 0            3649            SAFEWAY #1490       2300 16th St
# 1             184             RADIO HABANA   1109 VALENCIA St
# 2            1154     SUNFLOWER RESTAURANT    506 Valencia St
# 3            1636                     AXUM      698 Haight St
# 4            7764   YASUKOCHI'S SWEET SHOP     1790 SUTTER St
# ...           ...                      ...                ...
# 5200        67237                  La Jefa  445 Bayshore Blvd
# 5201        68442             Sauce Belden       56 Belden Pl
# 5202        67330  San Tung Restaurant LLC     1031 Irving St
# 5203        69769       Whole Foods Market     1150 Ocean Ave
# 5204        71476  Chou Chou Bakery Bistro     400 Dewey Blvd
#
#       business_postal_code  business_latitude  business_longitude  \
# 0                    94103          37.765708         -122.409002
# 1                    94110          37.755124         -122.420916
# 2                    94103          37.764678         -122.421905
# 3                    94117          37.771738         -122.433583
# 4                    94115          37.786590         -122.429815
# ...                    ...                ...                 ...
# 5200                 94107          37.749871         -122.405648
# 5201                 94104          37.791458         -122.403787
# 5202                 94122          37.763891         -122.468805
# 5203                 94112          37.723652         -122.454610
# 5204                 94116          37.747174         -122.459368
#
#       inspection_id inspection_date  inspection_score        inspection_type  \
# 0        -152048954      2017-12-06                82  Routine - Unscheduled
# 1        1240311029      2018-02-13                90  Routine - Unscheduled
# 2        -543926665      2019-03-27                46  Routine - Unscheduled
# 3         411423755      2018-10-03                88  Routine - Unscheduled
# 4        -968899858      2018-07-18                90  Routine - Unscheduled
# ...             ...             ...               ...                    ...
# 5200     2096352674      2017-09-14                84  Routine - Unscheduled
# 5201    -1957679603      2019-02-21                88  Routine - Unscheduled
# 5202    -1488539920      2018-02-08                88  Routine - Unscheduled
# 5203     1893281909      2017-06-13                88  Routine - Unscheduled
# 5204      794600084      2018-06-28                92  Routine - Unscheduled
#
#       violation_id                              violation_description  \
# 0       1478316123                   Moderate risk vermin infestation
# 1       1783429657            Insufficient hot water or running water
# 2        878370447  Inadequate and inaccessible handwashing facili...
# 3        247884717  Wiping cloths not clean or properly stored or ...
# 4       1814407794       Unclean or degraded floors walls or ceilings
# ...            ...                                                ...
# 5200     611762034       Unclean or degraded floors walls or ceilings
# 5201     850358329                        Low risk vermin infestation
# 5202    1255616242       Unclean or degraded floors walls or ceilings
# 5203     195484180  Inadequately cleaned or sanitized food contact...
# 5204    1069572052  Inadequately cleaned or sanitized food contact...
#
#       risk_category        date                time
# 0     Moderate Risk  2017-12-06 1970-01-01 12:00:00
# 1     Moderate Risk  2018-02-13 1970-01-01 12:00:00
# 2     Moderate Risk  2019-03-27 1970-01-01 12:00:00
# 3          Low Risk  2018-10-03 1970-01-01 12:00:00
# 4          Low Risk  2018-07-18 1970-01-01 12:00:00
# ...             ...         ...                 ...
# 5200       Low Risk  2017-09-14 1970-01-01 12:00:00
# 5201       Low Risk  2019-02-21 1970-01-01 12:00:00
# 5202       Low Risk  2018-02-08 1970-01-01 12:00:00
# 5203  Moderate Risk  2017-06-13 1970-01-01 12:00:00
# 5204  Moderate Risk  2018-06-28 1970-01-01 12:00:00
#
# [5205 rows x 15 columns]

# %%
pandas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5205 entries, 0 to 5204
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   business_id            5205 non-null   int32
#  1   business_name          5205 non-null   object
#  2   business_address       5205 non-null   object
#  3   business_postal_code   5205 non-null   int32
#  4   business_latitude      5205 non-null   float64
#  5   business_longitude     5205 non-null   float64
#  6   inspection_id          5205 non-null   int32
#  7   inspection_date        5205 non-null   object
#  8   inspection_score       5205 non-null   int32
#  9   inspection_type        5205 non-null   object
#  10  violation_id           5205 non-null   int32
#  11  violation_description  5205 non-null   object
#  12  risk_category          5205 non-null   object
#  13  date                   5205 non-null   object
#  14  time                   5205 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int32(5), object(7)
# memory usage: 508.4+ KB

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_date, to_timestamp, isnotnull

# Initialize Spark Session
spark = SparkSession.builder.appName("ChangeColumnTypes").getOrCreate()

# Set legacy time parser policy
spark.conf.set("spark.sql.legacy.timeParserPolicy", "LEGACY")

# Convert Spark DataFrame back to Pandas DataFrame if needed
# pandas_df = df_cleaned.toPandas()

# Create a Spark DataFrame from the Pandas DataFrame
spark_df = spark.createDataFrame(pandas_df)

# Now apply withColumn to the Spark DataFrame (spark_df)
df_cleaned = spark_df.withColumn("business_id", col("business_id").cast("int")) \
               .withColumn("inspection_id", col("inspection_id").cast("int")) \
               .withColumn("inspection_score", col("inspection_score").cast("int")) \
               .withColumn("violation_id", col("violation_id").cast("int")) \
               .withColumn("business_postal_code", col("business_postal_code").cast("int")) \
               .withColumn("inspection_date", to_date(col("inspection_date"), "MM/dd/yyyy hh:mm:ss a")) \
               .withColumn("date", to_date(col("date"), "MM/dd/yyyy")) \
               .withColumn("time", to_timestamp(col("time"), "HH:mm:ss"))  # Convert time to timestamp

# Show Schema After Conversion
df_cleaned.printSchema()
# Out:
# root
#  |-- business_id: integer (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- business_address: string (nullable = true)
#  |-- business_postal_code: integer (nullable = true)
#  |-- business_latitude: double (nullable = true)
#  |-- business_longitude: double (nullable = true)
#  |-- inspection_id: integer (nullable = true)
#  |-- inspection_date: date (nullable = true)
#  |-- inspection_score: integer (nullable = true)
#  |-- inspection_type: string (nullable = true)
#  |-- violation_id: integer (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- risk_category: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- time: timestamp (nullable = true)

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# Drop unnecessary columns
columns_to_drop = ['business_name', 'business_address', 'inspection_type']
# 'date' and 'time' are dropped here
df = pandas_df.drop(columns=columns_to_drop, errors='ignore')

# Handle categorical variables
categorical_cols = df.select_dtypes(include='object').columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Check
df_encoded.head()
# Out:
#    business_id  business_postal_code  business_latitude  business_longitude  \
# 0         3649                 94103          37.765708         -122.409002
# 1          184                 94110          37.755124         -122.420916
# 2         1154                 94103          37.764678         -122.421905
# 3         1636                 94117          37.771738         -122.433583
# 4         7764                 94115          37.786590         -122.429815
#
#    inspection_id  inspection_score  violation_id                time  \
# 0     -152048954                82    1478316123 1970-01-01 12:00:00
# 1     1240311029                90    1783429657 1970-01-01 12:00:00
# 2     -543926665                46     878370447 1970-01-01 12:00:00
# 3      411423755                88     247884717 1970-01-01 12:00:00
# 4     -968899858                90    1814407794 1970-01-01 12:00:00
#
#    inspection_date_2016-10-05  inspection_date_2016-10-06  ...  \
# 0                       False                       False  ...
# 1                       False                       False  ...
# 2                       False                       False  ...
# 3                       False                       False  ...
# 4                       False                       False  ...
#
#    date_2019-09-19  date_2019-09-20  date_2019-09-23  date_2019-09-24  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    date_2019-09-25  date_2019-09-26  date_2019-09-30  date_2019-10-01  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    date_2019-10-02  date_2019-10-03
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
#
# [5 rows x 1318 columns]

# %%
df_encoded.dtypes
# Out:
# business_id               int32
# business_postal_code      int32
# business_latitude       float64
# business_longitude      float64
# inspection_id             int32
#                          ...
# date_2019-09-26            bool
# date_2019-09-30            bool
# date_2019-10-01            bool
# date_2019-10-02            bool
# date_2019-10-03            bool
# Length: 1318, dtype: object

# %% [markdown]
# # **REGRESSION**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR, SVC
from sklearn.metrics import mean_squared_error, accuracy_score, confusion_matrix, classification_report

# 6. Features & Target for Regression
X_reg = df_encoded.drop('inspection_score', axis=1)
y_reg = df_encoded['inspection_score']

# Convert datetime columns to numerical representation (e.g., Unix timestamp)
for col in X_reg.select_dtypes(include=['datetime64']).columns:
    X_reg[col] = X_reg[col].astype(np.int64) // 10**9  # Convert to Unix timestamp

# 7. Train-Test Split
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)

# 8. Apply StandardScaler (only for Linear Regression and SVM)
scaler = StandardScaler()
X_train_reg_scaled = scaler.fit_transform(X_train_reg)
X_test_reg_scaled = scaler.transform(X_test_reg)

# 9. Train Models
# Linear Regression (Scaled)
lr = LinearRegression()
lr.fit(X_train_reg_scaled, y_train_reg)
y_pred_lr = lr.predict(X_test_reg_scaled)

# Random Forest Regressor (No Scaling Needed)
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_reg, y_train_reg)
y_pred_rf = rf_reg.predict(X_test_reg)

# SVR (Scaled)
svr = SVR()
svr.fit(X_train_reg_scaled, y_train_reg)
y_pred_svr = svr.predict(X_test_reg_scaled)

# 10. Evaluate Regression Models
rmse_lr = mean_squared_error(y_test_reg, y_pred_lr) ** 0.5  # Calculate RMSE manually
rmse_rf = mean_squared_error(y_test_reg, y_pred_rf) ** 0.5  # Calculate RMSE manually
rmse_svr = mean_squared_error(y_test_reg, y_pred_svr) ** 0.5  # Calculate RMSE manually


print(f"Linear Regression RMSE: {rmse_lr}")
print(f"Random Forest Regressor RMSE: {rmse_rf}")
print(f"SVR RMSE: {rmse_svr}")
# Out:
# Linear Regression RMSE: 5.702782186389993
# Random Forest Regressor RMSE: 3.259877062561767
# SVR RMSE: 7.140268092985499

# %%
plt.figure(figsize=(8, 5))

rmse_values = [rmse_lr, rmse_rf, rmse_svr]
model_names = ['Linear Regression', 'Random Forest', 'SVR']

plt.bar(model_names, rmse_values, color=['blue', 'green', 'purple'], alpha=0.7)
plt.xlabel('Regression Models', fontsize=12)
plt.ylabel('RMSE (Lower is Better)', fontsize=12)
plt.title('Regression Models RMSE Comparison', fontsize=14)
plt.grid(axis='y', linestyle="--", alpha=0.6)

plt.show()

# %%
print("📊 Report: Regression Models RMSE Analysis")
print("That the Random Forest model has the lowest RMSE, making it the best performer in this comparison.")
# Out:
# 📊 Report: Regression Models RMSE Analysis
# That the Random Forest model has the lowest RMSE, making it the best performer in this comparison.

# %% [markdown]
# # **CLASSIFICATION**

# %%
# 12. Features & Target for Classification
target_col = [col for col in df_encoded.columns if 'risk_category' in col][0]
X_clf = df_encoded.drop(target_col, axis=1)
y_clf = df_encoded[target_col]

# Convert datetime columns to numerical representation (e.g., Unix timestamp)
for col in X_clf.select_dtypes(include=['datetime64']).columns:
    X_clf[col] = X_clf[col].astype(np.int64) // 10**9  # Convert to Unix timestamp


# 13. Train-Test Split
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(X_clf, y_clf, test_size=0.2, random_state=42)

# 14. Apply StandardScaler (only for Logistic Regression and SVM)
X_train_clf_scaled = scaler.fit_transform(X_train_clf)
X_test_clf_scaled = scaler.transform(X_test_clf)

# 15. Train Classification Models
# Logistic Regression (Scaled)
logr = LogisticRegression(max_iter=1000)
logr.fit(X_train_clf_scaled, y_train_clf)
y_pred_logr = logr.predict(X_test_clf_scaled)

# Random Forest Classifier (No Scaling Needed)
rfc = RandomForestClassifier()
rfc.fit(X_train_clf, y_train_clf)
y_pred_rfc = rfc.predict(X_test_clf)

# SVM Classifier (Scaled)
svc = SVC()
svc.fit(X_train_clf_scaled, y_train_clf)
y_pred_svc = svc.predict(X_test_clf_scaled)

# 16. Evaluate Classification Models
acc_logr = accuracy_score(y_test_clf, y_pred_logr)
acc_rfc = accuracy_score(y_test_clf, y_pred_rfc)
acc_svc = accuracy_score(y_test_clf, y_pred_svc)

print(f"Logistic Regression Accuracy: {acc_logr}")
print(f"Random Forest Classifier Accuracy: {acc_rfc}")
print(f"SVM Classifier Accuracy: {acc_svc}")
# Out:
# Logistic Regression Accuracy: 0.9942363112391931
# Random Forest Classifier Accuracy: 0.9932756964457252
# SVM Classifier Accuracy: 0.9125840537944284

# %%
# 17. Line Chart: Classification Accuracy Comparison
plt.figure(figsize=(8, 5))

accuracy_values = [acc_logr, acc_rfc, acc_svc]
model_names = ['Logistic Regression', 'Random Forest', 'SVM']

plt.bar(model_names, accuracy_values, color=['blue', 'green', 'purple'], alpha=0.7)
plt.xlabel('Classification Models', fontsize=12)
plt.ylabel('Accuracy (Higher is Better)', fontsize=12)
plt.title('Classification Models Accuracy Comparison', fontsize=14)
plt.ylim(0, 1)  # Accuracy ranges from 0 to 1
plt.grid(axis='y', linestyle="--", alpha=0.6)

plt.show()

# %%
print("📊 Report: Classification Models Accuracy Analysis")
print("Random Forest Classifier achieves the highest accuracy, proving it's the best model for risk classification. Logistic Regression performs decently, while SVM has slightly lower accuracy.")
# Out:
# 📊 Report: Classification Models Accuracy Analysis
# Random Forest Classifier achieves the highest accuracy, proving it's the best model for risk classification. Logistic Regression performs decently, while SVM has slightly lower accuracy.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# Assuming risk_category column exists
# Check column names first
print(pandas_df.columns)

# Let's say column name is 'risk_category_Low' or similar after encoding
target_col = [col for col in df_encoded.columns if 'risk_category' in col][0]

# Features and Target
X_class = df_encoded.drop(target_col, axis=1)
y_class = df_encoded[target_col]

# Convert datetime columns to numerical representation (e.g., Unix timestamp)
for col in X_class.select_dtypes(include=['datetime64']).columns:
    X_class[col] = X_class[col].astype(np.int64) // 10**9  # Convert to Unix timestamp

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_class, y_class, test_size=0.2, random_state=42)

# Apply StandardScaler (only for Logistic Regression and SVM)
scaler = StandardScaler() # Initialize StandardScaler
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression
logr = LogisticRegression(max_iter=1000)
logr.fit(X_train_scaled, y_train)  # Use scaled data for Logistic Regression
y_pred_logr = logr.predict(X_test_scaled)  # Use scaled data for prediction

# Random Forest Classifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred_rfc = rfc.predict(X_test)

# SVM Classifier
svc = SVC()
svc.fit(X_train_scaled, y_train)  # Use scaled data for SVM
y_pred_svc = svc.predict(X_test_scaled)  # Use scaled data for prediction

# Evaluation
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_logr))
print(confusion_matrix(y_test, y_pred_logr))
print(classification_report(y_test, y_pred_logr))

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rfc))
print(confusion_matrix(y_test, y_pred_rfc))
print(classification_report(y_test, y_pred_rfc))

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svc))
print(confusion_matrix(y_test, y_pred_svc))
print(classification_report(y_test, y_pred_svc))
# Out:
# Index(['business_id', 'business_name', 'business_address',
#        'business_postal_code', 'business_latitude', 'business_longitude',
#        'inspection_id', 'inspection_date', 'inspection_score',
#        'inspection_type', 'violation_id', 'violation_description',
#        'risk_category', 'date', 'time'],
#       dtype='object')
# Logistic Regression Accuracy: 0.9942363112391931
# [[546   6]
#  [  0 489]]
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99       552
#         True       0.99      1.00      0.99       489
#
#     accuracy                           0.99      1041
#    macro avg       0.99      0.99      0.99      1041
# weighted avg       0.99      0.99      0.99      1041
#
# Random Forest Accuracy: 0.9932756964457252
# [[545   7]
#  [  0 489]]
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99       552
#         True       0.99      1.00      0.99       489
#
#     accuracy                           0.99      1041
#    macro avg       0.99      0.99      0.99      1041
# weighted avg       0.99      0.99      0.99      1041
#
# SVM Accuracy: 0.9125840537944284
# [[500  52]
#  [ 39 450]]
#               precision    recall  f1-score   support
#
#        False       0.93      0.91      0.92       552
#         True       0.90      0.92      0.91       489
#
#     accuracy                           0.91      1041
#    macro avg       0.91      0.91      0.91      1041
# weighted avg       0.91      0.91      0.91      1041

# %% [markdown]
# # **Confusion Matrix (Classification Results)**

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# For Random Forest Classifier
ConfusionMatrixDisplay.from_estimator(rfc, X_test, y_test, cmap='Blues')
plt.title('Random Forest Classifier - Confusion Matrix')
plt.show()

# Similarly, for Logistic Regression:
ConfusionMatrixDisplay.from_estimator(logr, X_test, y_test, cmap='Greens')
plt.title('Logistic Regression - Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # **Feature vs. Target (Trend Lines)**

# %%
plt.figure(figsize=(12, 5))
pandas_df.groupby('inspection_date')['inspection_score'].mean().plot(kind='line', marker='o')
plt.title('Trend of Inspection Scores Over Time')
plt.xlabel('Inspection Date')
plt.ylabel('Average Inspection Score')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='risk_category', data=pandas_df, palette="coolwarm")  # Changed df_viz to pandas_df
plt.xlabel("Risk Category", fontsize=12)
plt.ylabel("Number of Inspections", fontsize=12)
plt.title("📊 Number of Inspections per Risk Category", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
# Out:
# <ipython-input-33-aaa391cc16ef>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='risk_category', data=pandas_df, palette="coolwarm")  # Changed df_viz to pandas_df
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='risk_category', y='inspection_score', data=pandas_df, palette="coolwarm", inner="quartile")  # Changed df_viz to pandas_df
plt.xlabel("Risk Category", fontsize=12)
plt.ylabel("Inspection Score", fontsize=12)
plt.title("🎻 Violin Plot: Inspection Scores by Risk Category", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
# Out:
# <ipython-input-34-7253d7f1061a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='risk_category', y='inspection_score', data=pandas_df, palette="coolwarm", inner="quartile")  # Changed df_viz to pandas_df
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🚀 5️⃣ Bar Plot: Average Inspection Scores for Each Risk Category
plt.figure(figsize=(8, 5))
# Replaced 'df_viz' with 'pandas_df'
avg_scores = pandas_df.groupby('risk_category')['inspection_score'].mean()
sns.barplot(x=avg_scores.index, y=avg_scores.values, palette="coolwarm")
plt.xlabel("Risk Category", fontsize=12)
plt.ylabel("Average Inspection Score", fontsize=12)
plt.title("📊 Average Inspection Scores by Risk Category", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
# Out:
# <ipython-input-35-3c8461ff780e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_scores.index, y=avg_scores.values, palette="coolwarm")
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **Regression: Actual vs Predicted Plot**

# %%
# Group by risk category and count the most common violations
# Assuming 'risk_category_High Risk' is one of the one-hot encoded columns
# Adjust the column name if needed
target_col = [col for col in df_encoded.columns if 'risk_category' in col][0]  # Find the encoded risk category column

# Find violation description columns (after one-hot encoding)
violation_description_cols = [col for col in df_encoded.columns if 'violation_description' in col]

# Aggregate counts for each violation description within each risk category
violation_counts = df_encoded.groupby(target_col)[violation_description_cols].sum().reset_index()

# Melt the DataFrame to have violation descriptions in one column
violation_counts = violation_counts.melt(id_vars=[target_col], var_name='violation_description', value_name='count')

# Filter for the high-risk category and get the top 10 violations
high_risk_violations = violation_counts[(violation_counts[target_col] == 1) &
                                       (violation_counts['count'] > 0)].sort_values(by='count', ascending=False).head(10)

# Plot the most frequent violations in high-risk establishments
plt.figure(figsize=(12, 6))
sns.barplot(data=high_risk_violations,
            y='violation_description', x='count', palette="Reds")

plt.xlabel("Number of Occurrences")
plt.ylabel("Violation Type")
plt.title("🚨 Most Common Violations in High-Risk Establishments")
plt.show()
# Out:
# <ipython-input-36-cb2cd6d7c0d5>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=high_risk_violations,
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128680 (\N{POLICE CARS REVOLVING LIGHT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# What You Can Learn From This Plot
# If points closely follow the red dashed line, your model is accurate.
# If points deviate a lot, your model has prediction errors.
# If the green trend line diverges, your model has bias (systematic under/over-prediction).

# %% [markdown]
# # **Classification Report as Heatmap**

# %%
from sklearn.metrics import classification_report
import pandas as pd

# Generate classification report
report = classification_report(y_test, y_pred_rfc, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_report.iloc[:-1, :-1], annot=True, cmap='coolwarm')
plt.title('Random Forest Classifier - Classification Report')
plt.show()

# %%
pip install streamlit scikit-learn pandas numpy
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.43.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.25.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.30.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder  # Import LabelEncoder



# Define Features & Target for Score Prediction
# df_encoded is already a Pandas DataFrame, no need to convert
# Find the encoded risk category column
risk_category_col = [col for col in df_encoded.columns if 'risk_category' in col][0]
X_score = df_encoded.drop(['inspection_score', risk_category_col], axis=1)  # Features
y_score = df_encoded['inspection_score']  # Target Variable

# Define Features & Target for Risk Category Prediction
# df_cleaned needs to be converted to a Pandas DataFrame if it's a Spark DataFrame
# Instead of df_cleaned, use df_encoded here since it has the risk_category columns
X_risk = df_encoded.drop(['inspection_score', risk_category_col], axis=1)  # Use df_encoded
y_risk = df_encoded[risk_category_col]  # df_encoded is already a Pandas DataFrame

# ---->  Convert 'date' and 'time' columns to numerical representation <----
for col in ['date', 'time']:
    if col in X_score.columns:
        X_score[col] = pd.to_numeric(X_score[col])
        X_risk[col] = pd.to_numeric(X_risk[col]) # Apply the same conversion to X_risk


# ---->  Encode categorical features using LabelEncoder <----
for col in X_score.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    X_score[col] = le.fit_transform(X_score[col])
    X_risk[col] = le.fit_transform(X_risk[col]) # Apply the same encoding to X_risk

# Train-Test Split
X_train_score, X_test_score, y_train_score, y_test_score = train_test_split(X_score, y_score, test_size=0.2, random_state=42)
X_train_risk, X_test_risk, y_train_risk, y_test_risk = train_test_split(X_risk, y_risk, test_size=0.2, random_state=42)

# Train Models
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_score, y_train_score)

rf_clf = RandomForestClassifier()
rf_clf.fit(X_train_risk, y_train_risk)

# Save Models
pickle.dump(rf_reg, open("inspection_score_model.pkl", "wb"))
pickle.dump(rf_clf, open("risk_category_model.pkl", "wb"))

# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle

# Load trained models
rf_reg = pickle.load(open("inspection_score_model.pkl", "rb"))
rf_clf = pickle.load(open("risk_category_model.pkl", "rb"))

# App Title
st.title("🏢 Restaurant Inspection Score & Risk Prediction")

# User Inputs for Violation Data
st.sidebar.header("📋 Input Violation Data")

# Get the feature names the model was trained on
feature_names = rf_reg.feature_names_in_

# Create input fields dynamically based on feature names
input_values = {}
for feature in feature_names:
    if feature in ['date', 'time']:  # Handle numerical features (date, time)
        input_values[feature] = st.sidebar.number_input(f"Enter value for {feature}:", value=0.0)
    else:  # Handle other features (mostly categorical after encoding)
        input_values[feature] = st.sidebar.number_input(f"Enter value for {feature}:", value=0, min_value=0, max_value=1, step=1) # Assume categorical and encoded

# Create input data as a DataFrame with correct feature names
input_data = pd.DataFrame([input_values], columns=feature_names)

# Predict Inspection Score
score_prediction = rf_reg.predict(input_data)[0]

# Predict Risk Category
risk_prediction = rf_clf.predict(input_data)[0]

# Display Predictions
st.subheader("📊 Prediction Results")
st.write(f"🔢 **Predicted Inspection Score:** {round(score_prediction, 2)}")
st.write(f"⚠️ **Predicted Risk Category:** {risk_prediction}")

# Display Alerts
if score_prediction < 70:
    st.error("🚨 Warning: The predicted score is low, indicating a failed inspection!")
elif score_prediction < 85:
    st.warning("⚠️ The predicted score suggests a moderate risk of violations.")
else:
    st.success("✅ The predicted score suggests good compliance with food safety regulations.")

if risk_prediction == "High Risk":
    st.error("⚠️ This establishment falls into the HIGH-RISK category!")
elif risk_prediction == "Moderate Risk":
    st.warning("🔶 This establishment falls into the MODERATE-RISK category.")
else:
    st.success("✅ This establishment falls into the LOW-RISK category.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-03-19 20:50:28.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.911 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:28.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:29.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
# 2025-03-19 20:50:45.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:45.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-19 20:50:46.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !pip install streamlit pyngrok --quiet

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import pickle

# Load trained models
rf_reg = pickle.load(open("inspection_score_model.pkl", "rb"))
rf_clf = pickle.load(open("risk_category_model.pkl", "rb"))

# App Title
st.title("🏢 Restaurant Inspection Score & Risk Prediction")

# User Inputs for Violation Data
st.sidebar.header("📋 Input Violation Data")

# Example input fields (Customize based on available features)
feature1 = st.sidebar.slider("🚨 Number of Critical Violations", 0, 10, 1)
feature2 = st.sidebar.slider("🍽️ Number of Non-Critical Violations", 0, 20, 3)
feature3 = st.sidebar.selectbox("🧼 Cleanliness Level", ["Good", "Average", "Poor"])
feature4 = st.sidebar.selectbox("🔬 Presence of Foodborne Bacteria?", ["No", "Yes"])
feature5 = st.sidebar.slider("❄️ Temperature Control Violations", 0, 5, 1)

# Convert categorical inputs to numerical
cleanliness_map = {"Good": 3, "Average": 2, "Poor": 1}
bacteria_map = {"No": 0, "Yes": 1}

input_data = np.array([[feature1, feature2, cleanliness_map[feature3], bacteria_map[feature4], feature5]])

# Predict Inspection Score
score_prediction = rf_reg.predict(input_data)[0]

# Predict Risk Category
risk_prediction = rf_clf.predict(input_data)[0]

# Display Predictions
st.subheader("📊 Prediction Results")
st.write(f"🔢 **Predicted Inspection Score:** {round(score_prediction, 2)}")
st.write(f"⚠️ **Predicted Risk Category:** {risk_prediction}")

# Display Alerts
if score_prediction < 70:
    st.error("🚨 Warning: The predicted score is low, indicating a failed inspection!")
elif score_prediction < 85:
    st.warning("⚠️ The predicted score suggests a moderate risk of violations.")
else:
    st.success("✅ The predicted score suggests good compliance with food safety regulations.")

if risk_prediction == "High Risk":
    st.error("⚠️ This establishment falls into the HIGH-RISK category!")
elif risk_prediction == "Moderate Risk":
    st.warning("🔶 This establishment falls into the MODERATE-RISK category.")
else:
    st.success("✅ This establishment falls into the LOW-RISK category.")
# Out:
# Overwriting app.py

# %%
# !ngrok authtoken 2uYA27aX3eUrgq13k3KmSAkYOu9_7YdKbXtUDWJYMi6c7DDbs
from pyngrok import ngrok

# Kill any previous tunnels
# !pkill -9 streamlit
# !pkill -9 ngrok

# Run Streamlit in the background
# !streamlit run app.py &>/dev/null &

# Create a public URL using ngrok, specifying the correct protocol for Streamlit
# The 'addr' argument is used to specify the port and protocol
url = ngrok.connect(addr="8501", proto="http").public_url  # Change to 'http'
print(f"🚀 Open Streamlit App Here: {url}")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# WARNING:pyngrok.process.ngrok:t=2025-03-19T20:51:04+0000 lvl=warn msg="can't bind default web address, trying alternatives" obj=web addr=127.0.0.1:4040
# 🚀 Open Streamlit App Here: https://c61c-34-44-236-112.ngrok-free.app
